# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('main_data.csv')

# %%
df
# Out:
#                   Specialization  \
# 0               GENERAL PRACTICE
# 1               GENERAL PRACTICE
# 2               GENERAL PRACTICE
# 3               GENERAL PRACTICE
# 4               GENERAL PRACTICE
# 5               GENERAL PRACTICE
# 6               GENERAL PRACTICE
# 7               GENERAL PRACTICE
# 8               GENERAL PRACTICE
# 9               GENERAL PRACTICE
# 10                    GYNECOLOGY
# 11                    GYNECOLOGY
# 12                    GYNECOLOGY
# 13                    GYNECOLOGY
# 14                    GYNECOLOGY
# 15                    GYNECOLOGY
# 16                    GYNECOLOGY
# 17                    GYNECOLOGY
# 18                    GYNECOLOGY
# 19                    GYNECOLOGY
# 20      MENTAL HEALTH COUNSELLER
# 21      MENTAL HEALTH COUNSELLER
# 22      MENTAL HEALTH COUNSELLER
# 23      MENTAL HEALTH COUNSELLER
# 24      MENTAL HEALTH COUNSELLER
# 25      MENTAL HEALTH COUNSELLER
# 26      MENTAL HEALTH COUNSELLER
# ...

# %%
row1 = df.sample(frac =.9,random_state=101)

# %%
malicious = df.drop(row1.index)

# %%
non_mal1 = row1.sample(frac=.25,random_state=101)
row2 = row1.drop(non_mal1.index)

# %%
non_mal2 = row2.sample(frac=.3333333,random_state=101)
row3 = row2.drop(non_mal2.index)
non_mal3 = row3.sample(frac=.5,random_state=101)
non_mal4 = row3.drop(non_mal3.index)

# %%
malicious.to_csv("malicious.csv",index=False)

# %%
non_mal1.to_csv("sample1.csv",index=False)

# %%
non_mal2.to_csv("sample2.csv",index=False)

# %%
non_mal3.to_csv("sample3.csv",index=False)

# %%
non_mal4.to_csv("sample4.csv",index=False)

# %%
git remote add origin https://github.com/rathorekishan0/BE_Project.git
git push -u origin master
